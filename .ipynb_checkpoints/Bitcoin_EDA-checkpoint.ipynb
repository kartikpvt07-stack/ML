# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# ## Load Dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("/Users/ruhan/Downloads/btcusd_1-min_data (1).csv")

# %% [markdown]
# ## Question 1
# **What is the shape of the dataset?**

# %%
df.shape
# Out:
# (7623380, 6)

# %% [markdown]
# **Explanation:** Returns (rows, columns).

# %% [markdown]
# ## Question 2
# **Display first 5 rows.**

# %%
df.head()
# Out:
#    1767225600000000  87552.07000000  87552.07000000.1  87552.07000000.2  \
# 0  1767225660000000        87552.07          87552.07          87552.07
# 1  1767225720000000        87552.07          87552.07          87552.07
# 2  1767225780000000        87626.01          87626.01          87626.01
# 3  1767225840000000        87626.01          87626.01          87626.01
# 4  1767225900000000        87626.01          87626.01          87626.01
#
#    87552.07000000.3  0.00000000  1767225659999999  0.00000000.1  0  \
# 0          87552.07     0.00000  1767225719999999      0.000000  0
# 1          87552.07     0.00000  1767225779999999      0.000000  0
# 2          87626.01     0.00431  1767225839999999    377.668103  2
# 3          87626.01     0.00000  1767225899999999      0.000000  0
# 4          87626.01     0.00000  1767225959999999      0.000000  0
#
#    0.00000000.2  0.00000000.3  0.1
# 0       0.00000      0.000000    0
# 1       0.00000      0.000000    0
# ...

# %% [markdown]
# **Explanation:** Shows the first five records.

# %% [markdown]
# ## Question 3
# **Display last 5 rows.**

# %%
df.tail()
# Out:
#           Timestamp      Open      High       Low     Close    Volume
# 7623375  1782778560  60129.68  60138.72  60123.78  60138.61  0.087010
# 7623376  1782778620  60138.61  60138.61  60125.28  60128.73  0.019076
# 7623377  1782778680  60128.73  60128.73  60107.42  60107.42  0.027054
# 7623378  1782778740  60107.43  60107.43  60064.57  60070.57  5.223221
# 7623379  1782778800  60069.13  60078.45  60035.27  60045.97  1.068140

# %% [markdown]
# **Explanation:** Shows the last five records.

# %% [markdown]
# ## Question 4
# **Show column names.**

# %%
df.columns
# Out:
# Index(['Timestamp', 'Open', 'High', 'Low', 'Close', 'Volume'], dtype='object')

# %% [markdown]
# **Explanation:** Lists all columns.

# %% [markdown]
# ## Question 5
# **Display data types.**

# %%
df.dtypes
# Out:
# Timestamp      int64
# Open         float64
# High         float64
# Low          float64
# Close        float64
# Volume       float64
# dtype: object

# %% [markdown]
# **Explanation:** Shows the datatype of every column.

# %% [markdown]
# ## Question 6
# **Dataset information.**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7623380 entries, 0 to 7623379
# Data columns (total 6 columns):
#  #   Column     Dtype
# ---  ------     -----
#  0   Timestamp  int64
#  1   Open       float64
#  2   High       float64
#  3   Low        float64
#  4   Close      float64
#  5   Volume     float64
# dtypes: float64(5), int64(1)
# memory usage: 349.0 MB

# %% [markdown]
# **Explanation:** Displays summary including memory usage.

# %% [markdown]
# ## Question 7
# **Check missing values.**

# %%
df.isnull().sum()
# Out:
# Timestamp    0
# Open         0
# High         0
# Low          0
# Close        0
# Volume       0
# dtype: int64

# %% [markdown]
# ## Question 8
# **Check duplicate rows.**

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# ## Question 10
# **Summary statistics.**

# %%
df.describe()
# Out:
#           Timestamp          Open          High           Low         Close  \
# count  7.623380e+06  7.623380e+06  7.623380e+06  7.623380e+06  7.623380e+06
# mean   1.554077e+09  2.345817e+04  2.346636e+04  2.344981e+04  2.345819e+04
# std    1.320408e+08  3.131183e+04  3.132023e+04  3.130337e+04  3.131185e+04
# min    1.325376e+09  3.800000e+00  3.800000e+00  3.800000e+00  3.800000e+00
# 25%    1.439727e+09  4.559500e+02  4.560000e+02  4.557600e+02  4.559500e+02
# 50%    1.554077e+09  7.998140e+03  8.003220e+03  7.991880e+03  7.997790e+03
# 75%    1.668428e+09  3.814235e+04  3.816465e+04  3.811799e+04  3.814235e+04
# max    1.782779e+09  1.262020e+05  1.262720e+05  1.261580e+05  1.262020e+05
#
#              Volume
# count  7.623380e+06
# mean   4.990532e+00
# std    2.164817e+01
# min    0.000000e+00
# 25%    2.160000e-02
# 50%    4.488681e-01
# 75%    2.795228e+00
# max    5.853852e+03

# %% [markdown]
# ## Question 11
# **Minimum timestamp.**

# %%
df['Timestamp'].min()
# Out:
# 1325376060

# %% [markdown]
# ## Question 12
# **Maximum timestamp.**

# %%
df['Timestamp'].max()
# Out:
# 1782778800

# %% [markdown]
# ## Question 13
# **Average closing price.**

# %%
df['Close'].mean()
# Out:
# np.float64(23458.192582920074)

# %% [markdown]
# ## Question 14
# **Highest Bitcoin price.**

# %%
df['High'].max()
# Out:
# 126272.0

# %% [markdown]
# ## Question 15
# **Lowest Bitcoin price.**

# %%
df['Low'].min()
# Out:
# 3.8

# %% [markdown]
# ## Question 16
# **Highest trading volume.**

# %%
df['Volume'].max()
# Out:
# 5853.85216588

# %% [markdown]
# ## Question 17
# **Number of unique Open values.**

# %%
df['Open'].nunique()
# Out:
# 1792234

# %%
import matplotlib.pyplot as plt

# %%
price_cols = ["Open", "High", "Low", "Close"]

plt.figure(figsize=(10, 6))

plt.boxplot([df[col] for col in price_cols],
            labels=price_cols)

plt.title("Box Plot of Price Columns")
plt.ylabel("Price")

plt.show()
# Out:
# /var/folders/_j/jk6j0wwj6zld5s7wrx62txkm0000gn/T/ipykernel_881/1372112143.py:5: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df[col] for col in price_cols],

# %%
plt.figure(figsize=(10, 4))

plt.boxplot(df["Volume"], vert=False)

plt.title("Box Plot of Volume")

plt.show()
